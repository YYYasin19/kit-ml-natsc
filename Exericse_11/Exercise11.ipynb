# %% [markdown]
# # Exercise Sheet No. 11
#
# ---
#
# > Machine Learning for Natural Sciences, Summer 2021, Jun.-Prof. Pascal Friederich, pascal.friederich@kit.edu
# >
# > Deadline: 05.07.2021, 8 am
# >
# > Tutor: luca.torresi@kit.edu
# > **Please ask questions in the forum and only contact the Tutor when there are issues with the grading**
#
# ---
# **Topic**: This exercise sheet will introduce you to generative models in machine learning.

# %% [markdown]
# # Variational AutoEncoders
#
# In this exercise we will work on Variational AutoEncoders, first introduced by Welling and Kingma in a popular paper published in 2014 (https://arxiv.org/pdf/1312.6114.pdf).
# We will implement a vanilla version of VAE, with encoder and decoder composed of fully connected layers only, and try to use it for an anomaly detection task. We will then see how we can impose nice properties on the latent representation of data produced by the network simply augmenting it with a linear regressor.

# %%
# %matplotlib notebook
import numpy as np
import copy
import matplotlib.pyplot as plt
import seaborn as sb
from collections import Counter

from typing import Optional
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.nn.functional as F

from Utils import get_data, AbstractTrainer, plot_reconstr

# %% [markdown]
# Let's take a look at our data we will work on.
#
# The dataset consists of ECG segments of healthy patients and patients suffering from premature ventricular contraction (PVC). Segments were padded/cut to measure 350 time steps each.
#
# In the first part of the exercise we will implement a detector for anomalous hearbeats, thus our training and validation sets will consist of normal heartbeats only while in the test set we will have both normal and PVC ECGs.

# %%
np.random.seed(101)
train, val, test = get_data(batch_size=1)
print(f'Dimension of \n\t train set : {len(train)} data points \n\t validation set : {len(val)} data points \n\t test set : {len(test)} data points')
counts = Counter()
fig, axs = plt.subplots(nrows=2, ncols=3, sharex=True)
for batch in test:
    if sum(counts.values())==6:
            break
    data = batch['data']
    label = batch['labels']
    if label==0 and counts[0]<3:
        axs[0, counts[0]].plot(np.arange(350), data.squeeze())
        counts[0] += 1
    if label==1 and counts[1]<3:
        axs[1, counts[1]].plot(np.arange(350), data.squeeze())
        counts[1] += 1
axs[0,0].set_ylabel('Normal')
axs[1,0].set_ylabel('PVC')
fig.tight_layout()
fig.show()
# Out:
# Dimension of
# 	 train set : 6585 data points
# 	 validation set : 997 data points
# 	 test set : 1275 data points
# <div id='131faa3b-dc21-484e-8df9-b80e973f1f29'></div>

# %% [markdown]
# An autoencoder is an unsupervised representation learning algorithm based on neural networks that is used to learn efficient codings of unlabeled data. In particular, by imposing a bottleneck in the encoding layer of the network we can extract a compressed representation of the original input leveraging the structure present in it, i.e. the correlations among input features.
#
# In an AE input data is converted into a deterministic encoding vector, i.e. for each of the latent features the encoder outputs a single value. VAEs are an extension of AE int the sense that instead of performing a single value estimation of the latent vector they produce a probabilistic distribution $q_{\phi}(z|x)$ in the latent space. This is done through a variational bayesian inference: an approximation of the distribution is picked from some tractable family and then this is made as close as possible to the true posterior. In particular in the original formulation of VAE the prior imposed on the latent representation is a standard Gaussian and the mean field approximation is used, i.e. the latent variables are considered as independent from each other.
#
# Being the latent representation of our data a probabilistic distribution, to reconstruct input data we have to sample points from it $z$~$q_{\phi}(z|x)$. The fact that one of the nodes in the computational graph is a random node would create a problem in the backpropagation step because the gradient would not be able to 'flow' through it.
#
# One of the key elements in the VAE architecture is the so called 'reparameterization trick', that allow us to express a distribution $q_{\phi}(z|x)$ as a two-step generative process:
# 1. sample a noise variable $\epsilon$ from a simple distribution:
# 2. apply a deterministic transformation $g_{\phi}(\epsilon,x)$ that maps the random noise into a more complex distribution.
#
#
# In the case of Gaussian distributions the reparametrization trick is particularly simple: instead of writing $z$∼$q_{\phi}(z|x)=\mathcal{N}(\mu_{\phi}, \Sigma_{\phi})$ we can just write $z=g_{\phi}(\epsilon, x)= \mu_{\phi} +  \sigma_{\phi}*\epsilon$,  where $\epsilon$∼$\mathcal{N}(0,1)$.

# %% [markdown]
# In the following a partial implementation of a simple VAE with MLPs as encoder and decoder is provided. Complete the functions, paying attention to the fact that the encoder has to produce the logarithm of the standard deviation of each of the latent variables (this is done to ensure that the standard deviation is always positive).
#
# Hint: torch has a function similar to numpy.random.randn

# %%
class VAE(nn.Module):
    def __init__(self, input_dim : int = 350, embedding_dim : int = 30):
        super().__init__()
        self.embedding_dim = embedding_dim

        self.fc_input = nn.Sequential(nn.Linear(input_dim, 500),
                    nn.LeakyReLU(negative_slope=0.2),
                    nn.Dropout(0.4)
                    )
        self.fc_mean = nn.Linear(500, embedding_dim)
        self.fc_logstd = nn.Sequential(nn.Linear(500, embedding_dim),
                                    nn.LeakyReLU(negative_slope=0.05)
                                   )
        
        self.decoder = nn.Sequential(nn.Linear(embedding_dim, 500),
                    nn.LeakyReLU(negative_slope=0.2),
                    nn.Dropout(0.4),
                    nn.Linear(500, input_dim)
                    )

    def encode(self, x):
        '''
        The encoder is composed of a first fully connected layer followed by 
        two parallel linear layers that generate independently the mean and logstd of the latent distribution
        '''
        temp = None
        mean, logstd = None, None
        # YOUR CODE HERE
        temp = self.fc_input(x)
        mean = self.fc_mean(temp)
        logstd = self.fc_logstd(temp)
        return mean, logstd
        
    def reparameterize(self, mean, logstd): 
        '''
        Once the latent distribution is computed from the input a latent vector has to be sampled from it.
        We are working on gaussians, look at the formula in the block above 
        and remember that the encoder produces the logstd.
        
        std = None
        eps = None
        z = None
        # YOUR CODE HERE
        std = torch.exp(logstd)
        eps = torch.normal(0.0, 1.0, size=mean.shape) # torch.randn(self.embedding_dim)
        z = mean + std * eps
        return z
        '''
        '''
        Once the latent distribution is computed from the input a latent vector has to be sampled from it.
        We are working on gaussians, look at the formula in the block above 
        and remember that the encoder produces the logstd.
        '''
        std = None
        eps = None
        z = None
        
        std = torch.exp(logstd)
        eps = torch.normal(mean=0.0, std=1.0, size = mean.shape)
        
        z = mean + std * eps
        
        return z

    def forward(self, x):
        '''
        VAE computes the latent distribution associated with the input, 
        samples a vector from it and finally decodes it.
        '''
        mean, logstd = None, None
        z = None
        out = None 
        # YOUR CODE HERE
        mean, logstd = self.encode(x)
        z = self.reparameterize(mean, logstd)
        out = self.decoder(z)
        return [out, mean, logstd, z]

# %%
# encode - 1 point

vae = VAE(1,2)
m, s = vae.encode(torch.Tensor([1]))
assert m.shape==s.shape and m.shape==torch.Size([2]), 'error in encodings dimension'

# other hidden tests

# %%
# reparametrize - 1 point

vae = VAE(1,2)
s = vae.reparameterize(torch.Tensor([0,0]), torch.log(torch.tensor([1,1])))
assert s.size()==torch.Size([2]), 'error in dimension of generated random vector'

# other hidden tests

# %%
# forward - 1 point

# hidden tests...

# %% [markdown]
# What we want to maximize in variational Bayes methods is the ELBO, which stands for "evidence lower bound":
#
# $
# \begin{align}
# ELBO(\theta, \phi) = [\mathbb{E}_{q_{\phi}(z)}[\log p_{\theta}(x, z) - \log q_{\phi}(z|x)] ] = \\
# -KL[q_{\phi}(z|x)|| p_{\theta}(z)] + \frac{1}{L} \sum_{l=1}^{L} \log p_{\theta}(x|z^{(l)})
# \end{align}
# $
#
# where $q_{\phi}(z|x)$ represents the encoder and $\log p_{\theta}(x|z^{(l)})$ is the loglikelihood of the reconstruction and depends on the decoder parameters.
#
# The KL (Kullback–Leibler) divergence is a measure of how similar two probability distributions are (if equal -> KL=0) and it is also known as relative entropy. Note that the KL divergence is not a distance metric since it is not symmetric.
#
# The KL divergence of some families of distributions can be computed analytically and that's the case if we choose Gaussians priors and posteriors.
#
# Implement the KL divergence between a Gaussian posterior $q_{\phi}(z|x) = \mathcal{N}(\mu, \Sigma)$, where $\Sigma = diag(\sigma_{j})$ with $j \in {1, ..., J}$, and a standard Gaussian prior $p(z) = \mathcal{N}(0, I)$ : &emsp; $-\frac{1}{2} \sum_{j=1}^{J} (1 + \log((\sigma_{j})^{2}) - (\mu_{j})^{2} - (\sigma_{j})^2)$
#
# <br><br><br>
#
# <img src="vae.png" style="width: 500px;">

# %%
def KL_normnorm(mean, logstd):
    '''
    implement the closed form of KL divergence for a gaussian as posterior and a standard gaussian as prior
    '''
    kl = None
    # YOUR CODE HERE
    
    kl = -(1/2) * torch.sum(1+2*logstd-torch.square(mean)-torch.square(torch.exp(logstd)))
    return kl

# %%
# kl_divergence - 1 point

mean = torch.randn(3)
logstd = abs(torch.randn_like(mean))
try:
    KL_normnorm(mean, logstd).item()
except:
    print('KL divergence of two probability distributions is a number, not a vector...')

# other hidden tests

# %% [markdown]
# Differently from the original formulation of VAE we are going to multiply the KL divergence with a scalar parameter in such a way to regulate the tradeoff between the two terms of the ELBO loss (this is somehow similar to beta-VAE: https://openreview.net/references/pdf?id=Sy2fzU9gl). Then, as suggested in https://arxiv.org/pdf/1511.06349.pdf, we will initially set this parameter to zero and increase it linearly w.r.t. the number of epochs (this approach is termed KL warmup).

# %%
class VAE_Trainer(AbstractTrainer):
    def __init__(self, model : nn.Module, 
                 train_loader : Optional[DataLoader] = None, 
                 val_loader : Optional[DataLoader] = None,
                 test_loader : Optional[DataLoader] = None, 
                 optimizer = None):
        super().__init__(model=model,
                         train_loader = train_loader, 
                         val_loader = val_loader, 
                         test_loader = test_loader, 
                         optimizer = optimizer,
                         kl_scaling = 0.1)
        self.measures = {'loss' : [], 'reconstr' : []}

    def _loss(self, target, label, *args):
        out = args[0] 
        mean = args[1]
        logstd = args[2]
        batch_dim = target.shape[0]
        reconstr_error = self.reconstr_loss(out, target).sum()/batch_dim
        kl = KL_normnorm(mean, logstd)/batch_dim
        loss = reconstr_error + kl * self.kl_scaling * (self.ep/self.epochs) # kl * scaling * warmup_term
        return [loss, reconstr_error]

    def test(self):
        self.model.eval()
        reconstr_errors = []
        with torch.no_grad():
            for batch in self.train_loader:
                data = batch['data'].to(self.device)
                out, mean, logstd, z = self.model(data)
                reconstr_error = self.reconstr_loss(out, data).sum(-1)
                reconstr_errors.append(reconstr_error)
        reconstr_errors = torch.cat(reconstr_errors)
        thresh = torch.quantile(reconstr_errors, 0.85)
        print(f'reconstr_errors avg : {reconstr_errors.mean()}, thresh : {thresh}')
        fig, ax = plt.subplots()
        ax.hist(reconstr_errors.numpy(), bins=np.arange(0, 15, 0.125))
        ax.set_title('train')
        ax.axvline(x=thresh, c='red')
        fig.show()

        reconstr_errors = []
        labels = []
        with torch.no_grad():
            for batch in self.test_loader:
                data = batch['data'].to(self.device)
                label = batch['labels'].to(self.device).squeeze()
                out, mean, logstd, z = self.model(data)
                reconstr_error = self.reconstr_loss(out, data).sum(-1)
                reconstr_errors.append(reconstr_error)
                labels.append(label)
        reconstr_errors = torch.cat(reconstr_errors)
        labels = torch.cat(labels)

        outliers_error = reconstr_errors[labels==1]
        normal_error = reconstr_errors[labels==0]
        fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)
        ax1.hist(normal_error.numpy(), bins=np.arange(0, 15, 0.125))
        ax1.set_title('normal')
        ax1.axvline(x=thresh, c='red')
        ax2.hist(outliers_error.numpy(), bins=np.arange(0, 15, 0.125))
        ax2.set_title('anomalies')
        ax2.axvline(x=thresh, c='red')
        fig.show()
        print(f' avg recontruction error \n \t normal data : {normal_error.mean()}, anomalies : {outliers_error.mean()}')
        
        fig, ax = plt.subplots()
        preds = (reconstr_errors>thresh).float()
        cm = confusion_matrix(labels.numpy(), preds.numpy(), normalize='true')
        sb.heatmap(cm, square=True, xticklabels=False, yticklabels=False, 
                    annot=True, cbar=False, cmap="Reds", fmt='.2f').get_figure()
        ax.set_title('Anomaly detection: confusion matrix')
        fig.show()
        
        ##compute precision, recall and f1-score
        # precision = true_positive/(true_positive + false_positive)
        # recall = true_positive/(true_positive + false_negative)
        true = labels==1            
        tp = preds[true].sum()      # true_positive
        pos = (preds==1).sum()      # (true_positive + false_positive)
        true = true.sum()           # (true_positive + false_negative)
        
        precision = tp/pos
        recall = tp/true
        F1_score = 2*(precision * recall)/(precision + recall)
        
        print(f'Quality measures of our classifier:\n\t precision : {precision}\n\t recall : {recall}\n\t F1_score : {F1_score}')

# %% [markdown]
# We will now train our network on the 'normal' ECGs for a cycle of 100 epochs, without using any early stopping criteria, with a scaling constant of 0.1 for the KL divergence and using KL warmup. We will then use our VAE as anomaly detector on a test set composed of an equal (more or less) number of 'normal' and 'PVC' ECGs.
#
# To do so we will compute the distribution of the reconstruction errors over the training set, we will get the 0.85 (arbitrarily) quantile of the distribution and use it as a threshold to classify unseen data as belonging or not to the 'normal' class.
#
# Graphs produced are:
# 1. summary of training
# 2. few examples of reconstruction of test data
# 3. distribution of reconstruction errors on training set and 0.85 quantile in red
# 4. distribution of reconstruction errors on test set, separately for the 2 classes (threshold in red)
# 5. confusion matrix associated to our detector
#
# Three measures were computed to evaluate our classifier: precision, recall and F1 score. Check the code above to see how these are computed.

# %%
np.random.seed(66)
torch.manual_seed(66)

train_loader, val_loader, test_loader = get_data()
model = VAE()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

trainer = VAE_Trainer(model = model,
                      train_loader = train_loader, 
                      val_loader = val_loader, 
                      test_loader = test_loader, 
                      optimizer = optimizer)

model = trainer.train(plot=True)
plot_reconstr(model, test_loader)
trainer.test()
# Out:
# ===> epoch: 0
# Train	loss : 73.986559 reconstr : 73.986559
# Val	loss : 43.395504 reconstr : 43.395504
#
# ===> epoch: 1
# Train	loss : 50.511504 reconstr : 50.509089
# Val	loss : 27.145975 reconstr : 27.141354
#
# ===> epoch: 2
# Train	loss : 35.588879 reconstr : 35.568767
# Val	loss : 16.622705 reconstr : 16.59487
#
# ===> epoch: 3
# Train	loss : 23.22956 reconstr : 23.174387
# Val	loss : 12.947926 reconstr : 12.897712
#
# ===> epoch: 4
# Train	loss : 18.762647 reconstr : 18.684636
# Val	loss : 10.077211 reconstr : 9.997943
#
# ===> epoch: 5
# Train	loss : 15.858024 reconstr : 15.75359
# Val	loss : 10.130978 reconstr : 10.038104
#
# ===> epoch: 6
# Train	loss : 13.864088 reconstr : 13.741784
# Val	loss : 8.761674 reconstr : 8.640042
#
# ===> epoch: 7
# Train	loss : 12.62622 reconstr : 12.464529
# Val	loss : 8.445037 reconstr : 8.291406
#
# ===> epoch: 8
# Train	loss : 11.000452 reconstr : 10.805599
# Val	loss : 7.634377 reconstr : 7.443258
#
# ===> epoch: 9
# Train	loss : 9.907378 reconstr : 9.672204
# Val	loss : 7.029135 reconstr : 6.806685
#
# ===> epoch: 10
# Train	loss : 9.225635 reconstr : 8.947663
# Val	loss : 6.703906 reconstr : 6.437161
#
# ===> epoch: 11
# Train	loss : 8.471892 reconstr : 8.148359
# Val	loss : 7.190831 reconstr : 6.876541
#
# ===> epoch: 12
# Train	loss : 7.934542 reconstr : 7.558645
# Val	loss : 6.303507 reconstr : 5.944233
#
# ===> epoch: 13
# Train	loss : 7.611142 reconstr : 7.187244
# Val	loss : 5.975427 reconstr : 5.581384
#
# ===> epoch: 14
# Train	loss : 7.356985 reconstr : 6.899699
# Val	loss : 6.042456 reconstr : 5.607712
#
# ===> epoch: 15
# Train	loss : 7.019268 reconstr : 6.519629
# Val	loss : 5.780067 reconstr : 5.302233
#
# ===> epoch: 16
# Train	loss : 6.721481 reconstr : 6.164328
# Val	loss : 5.652607 reconstr : 5.125192
#
# ===> epoch: 17
# Train	loss : 6.452817 reconstr : 5.850692
# Val	loss : 5.484214 reconstr : 4.911241
#
# ===> epoch: 18
# Train	loss : 6.349587 reconstr : 5.710167
# Val	loss : 5.479079 reconstr : 4.882838
#
# ===> epoch: 19
# Train	loss : 6.319474 reconstr : 5.637156
# Val	loss : 5.475953 reconstr : 4.832035
#
# ===> epoch: 20
# Train	loss : 6.067255 reconstr : 5.346135
# Val	loss : 5.295895 reconstr : 4.61467
#
# ===> epoch: 21
# Train	loss : 6.048852 reconstr : 5.285684
# Val	loss : 5.071491 reconstr : 4.349638
#
# ===> epoch: 22
# Train	loss : 5.845562 reconstr : 5.053734
# Val	loss : 5.54812 reconstr : 4.809384
#
# ===> epoch: 23
# Train	loss : 5.949815 reconstr : 5.122194
# Val	loss : 5.905291 reconstr : 5.120298
#
# ===> epoch: 24
# Train	loss : 5.881046 reconstr : 5.025049
# Val	loss : 5.029608 reconstr : 4.23065
#
# ===> epoch: 25
# Train	loss : 5.85641 reconstr : 4.974773
# Val	loss : 5.011417 reconstr : 4.181554
#
# ===> epoch: 26
# Train	loss : 5.934103 reconstr : 5.012864
# Val	loss : 5.228599 reconstr : 4.344929
#
# ===> epoch: 27
# Train	loss : 5.895088 reconstr : 4.927332
# Val	loss : 5.102667 reconstr : 4.180163
#
# ===> epoch: 28
# Train	loss : 5.939694 reconstr : 4.955622
# Val	loss : 5.488053 reconstr : 4.539819
#
# ===> epoch: 29
# Train	loss : 5.890716 reconstr : 4.883036
# Val	loss : 5.110748 reconstr : 4.163362
#
# ===> epoch: 30
# Train	loss : 5.822998 reconstr : 4.804108
# Val	loss : 4.967861 reconstr : 4.006001
#
# ===> epoch: 31
# Train	loss : 5.682115 reconstr : 4.651533
# Val	loss : 5.367676 reconstr : 4.383718
#
# ===> epoch: 32
# Train	loss : 5.818841 reconstr : 4.768037
# Val	loss : 5.354685 reconstr : 4.359799
#
# ===> epoch: 33
# Train	loss : 5.762731 reconstr : 4.682618
# Val	loss : 5.182075 reconstr : 4.153311
#
# ===> epoch: 34
# Train	loss : 5.793044 reconstr : 4.695967
# Val	loss : 5.087422 reconstr : 4.039773
#
# ===> epoch: 35
# Train	loss : 5.822159 reconstr : 4.692178
# Val	loss : 5.089013 reconstr : 4.02086
#
# ===> epoch: 36
# Train	loss : 5.89034 reconstr : 4.747767
# Val	loss : 5.410415 reconstr : 4.307531
#
# ===> epoch: 37
# Train	loss : 5.917715 reconstr : 4.750127
# Val	loss : 5.469851 reconstr : 4.374964
#
# ===> epoch: 38
# Train	loss : 5.918355 reconstr : 4.746317
# Val	loss : 5.178517 reconstr : 4.039913
#
# ===> epoch: 39
# Train	loss : 5.989708 reconstr : 4.783873
# Val	loss : 5.594477 reconstr : 4.451527
#
# ===> epoch: 40
# Train	loss : 5.821312 reconstr : 4.610366
# Val	loss : 4.968836 reconstr : 3.816026
#
# ===> epoch: 41
# Train	loss : 5.65913 reconstr : 4.449556
# Val	loss : 5.253987 reconstr : 4.0949
#
# ===> epoch: 42
# Train	loss : 5.915849 reconstr : 4.687631
# Val	loss : 4.949657 reconstr : 3.766841
#
# ===> epoch: 43
# Train	loss : 5.91155 reconstr : 4.657523
# Val	loss : 5.195141 reconstr : 3.999614
#
# ===> epoch: 44
# Train	loss : 5.822917 reconstr : 4.563297
# Val	loss : 5.293365 reconstr : 4.093443
#
# ===> epoch: 45
# Train	loss : 5.912915 reconstr : 4.637515
# Val	loss : 5.418021 reconstr : 4.200104
#
# ===> epoch: 46
# Train	loss : 5.838717 reconstr : 4.557943
# Val	loss : 5.251755 reconstr : 4.043509
#
# ===> epoch: 47
# Train	loss : 5.940335 reconstr : 4.647156
# Val	loss : 5.25379 reconstr : 4.009519
#
# ===> epoch: 48
# Train	loss : 5.920587 reconstr : 4.599888
# Val	loss : 5.581328 reconstr : 4.32836
#
# ===> epoch: 49
# Train	loss : 6.009202 reconstr : 4.692279
# Val	loss : 5.204025 reconstr : 3.928241
#
# ===> epoch: 50
# Train	loss : 5.926845 reconstr : 4.578148
# Val	loss : 5.124477 reconstr : 3.840789
#
# ===> epoch: 51
# Train	loss : 5.725125 reconstr : 4.395172
# Val	loss : 5.115565 reconstr : 3.853035
#
# ===> epoch: 52
# Train	loss : 5.838434 reconstr : 4.497927
# Val	loss : 5.330228 reconstr : 4.042173
#
# ===> epoch: 53
# Train	loss : 6.081703 reconstr : 4.714931
# Val	loss : 5.346137 reconstr : 4.010548
#
# ===> epoch: 54
# Train	loss : 5.88634 reconstr : 4.488757
# Val	loss : 5.32232 reconstr : 3.980237
#
# ===> epoch: 55
# Train	loss : 6.056186 reconstr : 4.650351
# Val	loss : 5.319997 reconstr : 3.969693
#
# ===> epoch: 56
# Train	loss : 6.015822 reconstr : 4.5837
# Val	loss : 5.544478 reconstr : 4.172609
#
# ===> epoch: 57
# Train	loss : 5.928821 reconstr : 4.506255
# Val	loss : 5.479646 reconstr : 4.128757
#
# ===> epoch: 58
# Train	loss : 6.054542 reconstr : 4.633503
# Val	loss : 5.286465 reconstr : 3.925087
#
# ===> epoch: 59
# Train	loss : 5.954504 reconstr : 4.540305
# Val	loss : 5.52007 reconstr : 4.153305
#
# ===> epoch: 60
# Train	loss : 6.004528 reconstr : 4.569578
# Val	loss : 5.230877 reconstr : 3.851158
#
# ===> epoch: 61
# Train	loss : 5.893707 reconstr : 4.447122
# Val	loss : 5.060462 reconstr : 3.681352
#
# ===> epoch: 62
# Train	loss : 5.881416 reconstr : 4.435953
# Val	loss : 5.242222 reconstr : 3.86535
#
# ===> epoch: 63
# Train	loss : 5.878968 reconstr : 4.439689
# Val	loss : 5.162495 reconstr : 3.770028
#
# ===> epoch: 64
# Train	loss : 5.878911 reconstr : 4.41902
# Val	loss : 5.345722 reconstr : 3.95212
#
# ===> epoch: 65
# Train	loss : 5.953671 reconstr : 4.497875
# Val	loss : 5.174258 reconstr : 3.788591
#
# ===> epoch: 66
# Train	loss : 6.052313 reconstr : 4.600277
# Val	loss : 5.65326 reconstr : 4.266059
#
# ===> epoch: 67
# Train	loss : 5.941281 reconstr : 4.486209
# Val	loss : 5.635342 reconstr : 4.249427
#
# ===> epoch: 68
# Train	loss : 6.031109 reconstr : 4.582541
# Val	loss : 5.455564 reconstr : 4.064671
#
# ===> epoch: 69
# Train	loss : 6.163934 reconstr : 4.706453
# Val	loss : 5.707652 reconstr : 4.30045
#
# ===> epoch: 70
# Train	loss : 6.075718 reconstr : 4.603956
# Val	loss : 5.319304 reconstr : 3.91648
#
# ===> epoch: 71
# Train	loss : 6.074558 reconstr : 4.590287
# Val	loss : 5.268983 reconstr : 3.830447
#
# ===> epoch: 72
# Train	loss : 5.988761 reconstr : 4.47795
# Val	loss : 5.225808 reconstr : 3.780259
#
# ===> epoch: 73
# Train	loss : 5.962129 reconstr : 4.463424
# Val	loss : 4.975629 reconstr : 3.537557
#
# ===> epoch: 74
# Train	loss : 5.927148 reconstr : 4.431162
# Val	loss : 5.464128 reconstr : 4.030026
#
# ===> epoch: 75
# Train	loss : 5.832432 reconstr : 4.353112
# Val	loss : 5.247872 reconstr : 3.834458
#
# ===> epoch: 76
# Train	loss : 5.980397 reconstr : 4.508055
# Val	loss : 5.347068 reconstr : 3.920935
#
# ===> epoch: 77
# Train	loss : 6.08643 reconstr : 4.590531
# Val	loss : 5.566166 reconstr : 4.118852
#
# ===> epoch: 78
# Train	loss : 6.089904 reconstr : 4.586825
# Val	loss : 5.373694 reconstr : 3.937124
#
# ===> epoch: 79
# Train	loss : 6.032108 reconstr : 4.528198
# Val	loss : 5.38786 reconstr : 3.947803
#
# ===> epoch: 80
# Train	loss : 5.974955 reconstr : 4.45925
# Val	loss : 5.532957 reconstr : 4.074756
#
# ===> epoch: 81
# Train	loss : 5.986462 reconstr : 4.475698
# Val	loss : 5.406887 reconstr : 3.964233
#
# ===> epoch: 82
# Train	loss : 6.107356 reconstr : 4.587544
# Val	loss : 5.673075 reconstr : 4.203293
#
# ===> epoch: 83
# Train	loss : 6.002269 reconstr : 4.460449
# Val	loss : 5.459048 reconstr : 3.99784
#
# ===> epoch: 84
# Train	loss : 5.958141 reconstr : 4.438532
# Val	loss : 5.446482 reconstr : 3.988147
#
# ===> epoch: 85
# Train	loss : 5.971262 reconstr : 4.444657
# Val	loss : 5.368582 reconstr : 3.907275
#
# ===> epoch: 86
# Train	loss : 5.990858 reconstr : 4.468545
# Val	loss : 5.471818 reconstr : 4.024099
#
# ===> epoch: 87
# Train	loss : 1097.466863 reconstr : 4.641638
# Val	loss : 5.344596 reconstr : 3.848283
#
# ===> epoch: 88
# Train	loss : 6.166924 reconstr : 4.583607
# Val	loss : 5.223432 reconstr : 3.707812
#
# ===> epoch: 89
# Train	loss : 6.127986 reconstr : 4.554981
# Val	loss : 5.439854 reconstr : 3.926381
#
# ===> epoch: 90
# Train	loss : 5.943442 reconstr : 4.364173
# Val	loss : 5.393163 reconstr : 3.887082
#
# ===> epoch: 91
# Train	loss : 5.997965 reconstr : 4.429444
# Val	loss : 5.433256 reconstr : 3.92925
#
# ===> epoch: 92
# Train	loss : 5.966811 reconstr : 4.396786
# Val	loss : 5.543051 reconstr : 4.029604
#
# ===> epoch: 93
# Train	loss : 6.06268 reconstr : 4.489749
# Val	loss : 5.234682 reconstr : 3.715496
#
# ===> epoch: 94
# Train	loss : 5.956924 reconstr : 4.377222
# Val	loss : 5.332921 reconstr : 3.820887
#
# ===> epoch: 95
# Train	loss : 6.035953 reconstr : 4.453698
# Val	loss : 5.199031 reconstr : 3.685757
#
# ===> epoch: 96
# Train	loss : 5.992581 reconstr : 4.409341
# Val	loss : 5.550983 reconstr : 4.029771
#
# ===> epoch: 97
# Train	loss : 6.040562 reconstr : 4.460344
# Val	loss : 5.464934 reconstr : 3.940927
#
# ===> epoch: 98
# Train	loss : 5.999279 reconstr : 4.409806
# Val	loss : 5.309264 reconstr : 3.79306
#
# ===> epoch: 99
# Train	loss : 5.980382 reconstr : 4.406428
# Val	loss : 5.225258 reconstr : 3.708948
# Summary of training:
# <div id='d9217ca3-fdd5-4cc6-be21-346597cfc6f4'></div>
# Let's plot some reconstructed data:
# <div id='0e768aae-767f-40b7-8374-578013df7cd9'></div>
# <div id='a9fc997e-ac99-4c65-b692-8c2527265d06'></div>
# <div id='dd47aa7a-2e4e-4819-8dd5-a7cca3d59c84'></div>
# <div id='7f07208b-847c-4086-8b14-b06d8d5abfc7'></div>
# <div id='24c75d3d-f7bd-429e-8ee3-ad9717bdb75c'></div>
# reconstr_errors avg : 3.9018948078155518, thresh : 5.238183975219727
# <div id='fb94fa35-21b0-47cd-8a05-25cbf4a42b92'></div>
# <div id='2b4a11d5-b3d2-4f81-9e36-8bb1da8e8648'></div>
#  avg recontruction error
#  	 normal data : 3.795135974884033, anomalies : 9.160813331604004
# <div id='1754d117-5a56-480c-9a80-c0d67cbc6821'></div>
# Quality measures of our classifier:
# 	 precision : 0.875806450843811
# 	 recall : 0.8687999844551086
# 	 F1_score : 0.8722891211509705

# %% [markdown]
# A vantage of having a probabilistic representation of the encodings is that we can extract uncertainties over the reconstructed data. In the following cell we will perform a simple Monte Carlo evaluation of the uncertainties and plot confidence intervals around the mean reconstruction of the input.

# %%
torch.manual_seed(11)
data = next(iter(train_loader))['data'][0]
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True)
ax[0].plot(np.arange(350), data)

model.eval()
mean, logstd = model.encode(data)
reconstructed_l = []
for i in range(10):
    z = model.reparameterize(mean, logstd)
    reconstructed_l.append(model.decoder(z).unsqueeze(0))
reconstructed = torch.cat(reconstructed_l, axis=0)
mean = reconstructed.mean(axis=0).detach().numpy()
std = reconstructed.std(axis=0).detach().numpy()
ax[1].plot(np.arange(350), mean)
ax[1].fill_between(np.arange(350), mean + 2*std, mean - 2*std, alpha=0.2, edgecolor='blue')
fig.show()
# Out:
# <ipython-input-58-d67bf74e9ba8>:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# VAEs can be used to generate new datapoints. Once the network has been trained, we can sample latent representations from the prior distribution (in our case a standard gaussian) and decode them to produce new unseen data. The same mechanism is at the base of GANs.
#
# Try to produce new data yourself (the box is not graded).

# %%
torch.manual_seed(12)
size = model.embedding_dim
fig, axs = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True, figsize=(18,8))
for i in range(6):
    sample = None           # sample from the prior (standard normal)
    new_data = None         # feed the sample to the decoder to produce new data
    
    sample = torch.randn(size)
    new_data = model.decoder(sample).unsqueeze(0).mean(axis=0).detach().numpy()
    
    # if you get an error in the plot function, just have a look at how plots were produced in the block above
    axs[i%2,i%3].plot(np.arange(350), new_data)
# fig.show()

# %% [markdown]
# We have seen the basic structure of a VAE, tested it on a anomaly detection task and seen how new data can be generated by means of the decoder. We will now see how we can enforce simple properties on the representations in the latent space.
#
# By minimizing the KL we are forcing the representations (remember that these are distributions, not single values) produced by the encoder to be as close as possible to a standard normal. We could go beyond this and impose, for example, that the distributions of representations corresponding to different classes of data occupy different volumes of the latent space.
#
# Our training set will now consist of ECGs of both 'normal' and 'PVC' classes, we will train, in parallel to the VAE, a linear classifier on the means of the distributions produced by the encoder. In this way the means of the distributions corresponding to different classes will be pushed in linearly separable volumes of the latent space.

# %% [markdown]
# Implement a simple classifier of one single fully connected layer. Select the right activation function for a binary classifier (you have already encountered it in a previous exercise).
#
# Hint: torch.nn module has useful functions...

# %%
class Composed(nn.Module):
    def __init__(self, input_dim : int = 350, embedding_dim : int = 3):
        super().__init__()
        self.vae = VAE(input_dim, embedding_dim)
        self.classifier = BinaryClassifier(embedding_dim)
    def forward(self, data):
        out, mean, logstd, z = self.vae(data)
        logits = self.classifier(mean).squeeze()
        return [out, mean, logstd, z, logits]


class BinaryClassifier(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.fc = nn.Linear(in_features=input_dim, out_features=1)  # f(ully)c(onnected)
        self.activation = nn.Sigmoid()   # we need a differentiable function between 0 and 1... 
        
        
    def forward(self, data):
        return self.activation(self.fc(data))

# %%
# Binary_classifier - 1 point

# hidden tests (checking nn.layers)

# %% [markdown]
# Try to implement the loss of our new architecture. It will have to be composed by 3 additive terms: the likelihood for the reconstruction, the kl divergence for the prior and a term for the binary classifier.
#
# (For this task you may drop the KL warmup)
#
# Hints:
# 1. maybe you want to take a look at the VAE_Trainer loss function implemented above...
# 2. ComposedTrainer class has a new attribute. What is the BCELoss?
# 3. remember that you already implemented a function for the KL divergence
# 4. have you asked yourself what is the meaning of "reduction='none'" in the torch.nn functions we used?

# %%
class ComposedTrainer(AbstractTrainer):
    def __init__(self, model : nn.Module, 
                 train_loader : Optional[DataLoader] = None, 
                 val_loader : Optional[DataLoader] = None,
                 test_loader : Optional[DataLoader] = None, 
                 optimizer = None):
        super().__init__(model=model,
                         train_loader = train_loader,
                         val_loader = val_loader,
                         test_loader = test_loader,
                         optimizer = optimizer,
                         early_stop = 2)
        self.class_loss = nn.BCELoss(reduction='none')       
        self.measures = {'loss' : [], 'reconstr' : [], 'classif' : []}

    def _loss(self, target, label, *args):
        out = args[0] 
        mean = args[1]
        logstd = args[2]
        logits = args[4]
        batch_dim = target.shape[0]
        #                               <============================ THE FOLLOWING 4 LINES ONLY
        reconstr_error = self.reconstr_loss(out, target).sum()/batch_dim  # an old friend
        kl = KL_normnorm(mean, logstd)/batch_dim  # another old friend
        classif_error = self.class_loss(logits, label).sum()/batch_dim  # a new one
        loss = reconstr_error + self.kl_scaling * kl + classif_error               
        
        return [loss, reconstr_error, classif_error]

    def test(self):
        self.model.eval()
        means = []
        labels = []
        preds = []
        with torch.no_grad():
            for batch in self.val_loader:
                data = batch['data'].to(self.device)
                label = batch['labels'].to(self.device).squeeze()
                out, mean, logstd, z, logits = self.model(data)
                means.append(mean)
                labels.append(label)
                preds.append((logits>0.5).float())
        labels = torch.cat(labels).numpy().astype('int')
        preds = torch.cat(preds).numpy().astype('int')
        
        fig, ax = plt.subplots()
        cm = confusion_matrix(labels, preds, normalize='true')
        sb.heatmap(cm, square=True, xticklabels=False, yticklabels=False, 
                    annot=True, cbar=False, cmap="Reds", fmt='.2f').get_figure()
        ax.set_title('Classification: confusion matrix')
        # fig.show()


        means = torch.cat(means).numpy()
        colors={0: 'blue', 1:'red'}
        fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
        ax.scatter(means[:,0], means[:,1], means[:,2], marker=".", s=20, c=[colors[i] for i in labels])
        ax.set_title('Latent space')
        # fig.show()

# %%
# Composed_Loss - 1 point

# hidden tests... did you check the hints?

# %% [markdown]
# We will now train our network for a cycle of 100 epochs, using as early stopping criteria the classification error on the validation set, with a scaling constant of 0.5 for the KL divergence and using (or not) KL warmup.
#
# Graphs produced are:
# 1. summary of training
# 2. confusion matrix associated to the binary classifier
# 4. interactive 3D graph in the latent space of the means of the representation distributions produced by the encoder on the validation set

# %%
np.random.seed(666)
torch.manual_seed(666)

train_loader, val_loader, test_loader = get_data(composed=True)
model = Composed()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

trainer = ComposedTrainer(model = model,
                          train_loader = train_loader, 
                          val_loader = val_loader, 
                          test_loader = test_loader, 
                          optimizer = optimizer)

model = trainer.train(plot=True)
#     plot_reconstr(model, test_loader)
trainer.test()
# Out:
# ===> epoch: 0
# Train	loss : 61.876994 reconstr : 61.131463 classif : 0.736131
# Val	loss : 25.918457 reconstr : 25.178828 classif : 0.730288
# Model saved
#
# ===> epoch: 1
# Train	loss : 40.57633 reconstr : 39.811491 classif : 0.71752
# Val	loss : 19.957233 reconstr : 19.107569 classif : 0.716224
# Model saved
#
# ===> epoch: 2
# Train	loss : 26.750548 reconstr : 25.843705 classif : 0.702776
# Val	loss : 20.509265 reconstr : 19.4897 classif : 0.707687
# Model saved
#
# ===> epoch: 3
# Train	loss : 20.995766 reconstr : 19.815776 classif : 0.696503
# Val	loss : 18.640839 reconstr : 17.318804 classif : 0.692033
# Model saved
#
# ===> epoch: 4
# Train	loss : 16.76996 reconstr : 15.40239 classif : 0.68087
# Val	loss : 15.243195 reconstr : 13.836352 classif : 0.66537
# Model saved
#
# ===> epoch: 5
# Train	loss : 16.445206 reconstr : 14.855014 classif : 0.661976
# Val	loss : 13.572723 reconstr : 11.878842 classif : 0.678845
#
# ===> epoch: 6
# Train	loss : 14.77648 reconstr : 12.971811 classif : 0.666783
# Val	loss : 12.397513 reconstr : 10.547144 classif : 0.66446
# Model saved
#
# ===> epoch: 7
# Train	loss : 13.521467 reconstr : 11.560341 classif : 0.657772
# Val	loss : 13.286813 reconstr : 11.311416 classif : 0.662388
# Model saved
#
# ===> epoch: 8
# Train	loss : 13.328615 reconstr : 11.243589 classif : 0.646156
# Val	loss : 12.027811 reconstr : 9.892129 classif : 0.641864
# Model saved
#
# ===> epoch: 9
# Train	loss : 12.769029 reconstr : 10.584108 classif : 0.650355
# Val	loss : 12.689026 reconstr : 10.550773 classif : 0.650961
#
# ===> epoch: 10
# Train	loss : 12.058823 reconstr : 9.823122 classif : 0.651764
# Val	loss : 11.122932 reconstr : 8.905596 classif : 0.659375
#
# ===> epoch: 11
# Train	loss : 11.448641 reconstr : 9.217727 classif : 0.657288
# Val	loss : 11.632797 reconstr : 9.463949 classif : 0.66305
#
# ===> epoch: 12
# Train	loss : 11.623698 reconstr : 9.412648 classif : 0.64746
# Val	loss : 11.032664 reconstr : 8.88974 classif : 0.648703
#
# ===> epoch: 13
# Train	loss : 11.440361 reconstr : 9.232973 classif : 0.632905
# Val	loss : 10.554576 reconstr : 8.277046 classif : 0.625548
# Model saved
#
# ===> epoch: 14
# Train	loss : 11.025763 reconstr : 8.834682 classif : 0.604767
# Val	loss : 11.123455 reconstr : 8.99447 classif : 0.580311
# Model saved
#
# ===> epoch: 15
# Train	loss : 10.972081 reconstr : 8.796889 classif : 0.57813
# Val	loss : 10.894333 reconstr : 8.762375 classif : 0.568771
# Model saved
#
# ===> epoch: 16
# Train	loss : 11.0332 reconstr : 8.930737 classif : 0.574032
# Val	loss : 10.290212 reconstr : 8.202925 classif : 0.560703
# Model saved
#
# ===> epoch: 17
# Train	loss : 10.793133 reconstr : 8.705209 classif : 0.53105
# Val	loss : 10.443567 reconstr : 8.325553 classif : 0.483955
# Model saved
#
# ===> epoch: 18
# Train	loss : 11.025506 reconstr : 8.915724 classif : 0.479987
# Val	loss : 10.225271 reconstr : 8.079051 classif : 0.454919
# Model saved
#
# ===> epoch: 19
# Train	loss : 10.788704 reconstr : 8.616249 classif : 0.44804
# Val	loss : 9.590089 reconstr : 7.433971 classif : 0.426734
# Model saved
#
# ===> epoch: 20
# Train	loss : 10.345078 reconstr : 8.156055 classif : 0.423753
# Val	loss : 9.478233 reconstr : 7.284997 classif : 0.40388
# Model saved
#
# ===> epoch: 21
# Train	loss : 10.0908 reconstr : 7.905749 classif : 0.407692
# Val	loss : 10.149479 reconstr : 7.883752 classif : 0.401977
# Model saved
#
# ===> epoch: 22
# Train	loss : 10.350945 reconstr : 8.076535 classif : 0.418191
# Val	loss : 9.771911 reconstr : 7.528418 classif : 0.399339
# Model saved
#
# ===> epoch: 23
# Train	loss : 10.072536 reconstr : 7.804252 classif : 0.399876
# Val	loss : 9.353669 reconstr : 7.080984 classif : 0.375541
# Model saved
#
# ===> epoch: 24
# Train	loss : 9.951541 reconstr : 7.689854 classif : 0.384547
# Val	loss : 9.179506 reconstr : 6.883658 classif : 0.369437
# Model saved
#
# ===> epoch: 25
# Train	loss : 9.960503 reconstr : 7.727059 classif : 0.377368
# Val	loss : 9.208473 reconstr : 7.007613 classif : 0.360755
# Model saved
#
# ===> epoch: 26
# Train	loss : 9.895633 reconstr : 7.671489 classif : 0.370179
# Val	loss : 9.670087 reconstr : 7.498783 classif : 0.347394
# Model saved
#
# ===> epoch: 27
# Train	loss : 9.973609 reconstr : 7.721719 classif : 0.362108
# Val	loss : 9.402299 reconstr : 7.149861 classif : 0.34448
# Model saved
#
# ===> epoch: 28
# Train	loss : 9.884444 reconstr : 7.613022 classif : 0.351264
# Val	loss : 9.424534 reconstr : 7.187218 classif : 0.3301
# Model saved
#
# ===> epoch: 29
# Train	loss : 9.783482 reconstr : 7.54937 classif : 0.350569
# Val	loss : 9.79046 reconstr : 7.666189 classif : 0.317802
# Model saved
#
# ===> epoch: 30
# Train	loss : 9.687284 reconstr : 7.476921 classif : 0.330266
# Val	loss : 9.260569 reconstr : 7.005413 classif : 0.304916
# Model saved
#
# ===> epoch: 31
# Train	loss : 9.696314 reconstr : 7.455495 classif : 0.321217
# Val	loss : 8.859711 reconstr : 6.66442 classif : 0.303149
# Model saved
#
# ===> epoch: 32
# Train	loss : 9.630667 reconstr : 7.39626 classif : 0.313433
# Val	loss : 9.527625 reconstr : 7.324399 classif : 0.296799
# Model saved
#
# ===> epoch: 33
# Train	loss : 9.539684 reconstr : 7.341158 classif : 0.310234
# Val	loss : 9.326451 reconstr : 7.155666 classif : 0.293237
# Model saved
#
# ===> epoch: 34
# Train	loss : 9.504362 reconstr : 7.320301 classif : 0.30193
# Val	loss : 9.317686 reconstr : 7.165605 classif : 0.287345
# Model saved
#
# ===> epoch: 35
# Train	loss : 9.53716 reconstr : 7.358344 classif : 0.301162
# Val	loss : 9.059573 reconstr : 6.873408 classif : 0.286945
# Model saved
#
# ===> epoch: 36
# Train	loss : 9.561215 reconstr : 7.353441 classif : 0.295479
# Val	loss : 9.149893 reconstr : 6.990828 classif : 0.273031
# Model saved
#
# ===> epoch: 37
# Train	loss : 9.653781 reconstr : 7.434497 classif : 0.288472
# Val	loss : 9.50951 reconstr : 7.29136 classif : 0.263795
# Model saved
#
# ===> epoch: 38
# Train	loss : 9.561592 reconstr : 7.380659 classif : 0.281717
# Val	loss : 9.222967 reconstr : 7.088085 classif : 0.265374
#
# ===> epoch: 39
# Train	loss : 9.550211 reconstr : 7.352746 classif : 0.281702
# Val	loss : 8.979106 reconstr : 6.802999 classif : 0.261168
# Model saved
#
# ===> epoch: 40
# Train	loss : 9.461248 reconstr : 7.290732 classif : 0.274517
# Val	loss : 9.011603 reconstr : 6.841366 classif : 0.245222
# Model saved
#
# ===> epoch: 41
# Train	loss : 9.427802 reconstr : 7.25927 classif : 0.26582
# Val	loss : 9.028172 reconstr : 6.868204 classif : 0.254543
#
# ===> epoch: 42
# Train	loss : 9.27266 reconstr : 7.10316 classif : 0.262061
# Val	loss : 8.989661 reconstr : 6.865936 classif : 0.237183
# Model saved
#
# ===> epoch: 43
# Train	loss : 9.407046 reconstr : 7.271824 classif : 0.256579
# Val	loss : 9.266538 reconstr : 7.096602 classif : 0.239982
#
# ===> epoch: 44
# Train	loss : 9.44203 reconstr : 7.256492 classif : 0.252614
# Val	loss : 9.16662 reconstr : 6.998333 classif : 0.237273
#
# ===> epoch: 45
# Train	loss : 9.351626 reconstr : 7.171904 classif : 0.256199
# Val	loss : 9.129263 reconstr : 7.01295 classif : 0.236615
# Model saved
#
# ===> epoch: 46
# Train	loss : 9.527782 reconstr : 7.348211 classif : 0.251508
# Val	loss : 8.858096 reconstr : 6.662586 classif : 0.234613
# Model saved
#
# ===> epoch: 47
# Train	loss : 9.37607 reconstr : 7.205995 classif : 0.247726
# Val	loss : 9.292266 reconstr : 7.146545 classif : 0.228419
# Model saved
#
# ===> epoch: 48
# Train	loss : 9.441476 reconstr : 7.26172 classif : 0.244381
# Val	loss : 8.873915 reconstr : 6.665247 classif : 0.23086
#
# ===> epoch: 49
# Train	loss : 9.389568 reconstr : 7.204783 classif : 0.239498
# Val	loss : 8.961109 reconstr : 6.759042 classif : 0.219456
# Model saved
#
# ===> epoch: 50
# Train	loss : 9.268192 reconstr : 7.094028 classif : 0.238431
# Val	loss : 8.681108 reconstr : 6.546986 classif : 0.22067
#
# ===> epoch: 51
# Train	loss : 9.235126 reconstr : 7.104124 classif : 0.235128
# Val	loss : 8.737176 reconstr : 6.627371 classif : 0.216943
# Model saved
#
# ===> epoch: 52
# Train	loss : 9.34401 reconstr : 7.15792 classif : 0.230453
# Val	loss : 9.025463 reconstr : 6.84823 classif : 0.21101
# Model saved
#
# ===> epoch: 53
# Train	loss : 9.194219 reconstr : 7.03964 classif : 0.230185
# Val	loss : 8.737828 reconstr : 6.598606 classif : 0.208768
# Model saved
#
# ===> epoch: 54
# Train	loss : 9.288285 reconstr : 7.118844 classif : 0.228014
# Val	loss : 8.64851 reconstr : 6.551439 classif : 0.208183
# Model saved
#
# ===> epoch: 55
# Train	loss : 9.350075 reconstr : 7.249148 classif : 0.224231
# Val	loss : 8.704455 reconstr : 6.547086 classif : 0.208997
#
# ===> epoch: 56
# Train	loss : 9.368379 reconstr : 7.177557 classif : 0.223213
# Val	loss : 8.965704 reconstr : 6.791661 classif : 0.209374
#
# ===> epoch: 57
# Train	loss : 9.133293 reconstr : 7.004595 classif : 0.223033
# Val	loss : 8.773238 reconstr : 6.661463 classif : 0.19769
# Model saved
#
# ===> epoch: 58
# Train	loss : 9.373283 reconstr : 7.212905 classif : 0.213438
# Val	loss : 8.931789 reconstr : 6.767653 classif : 0.197881
#
# ===> epoch: 59
# Train	loss : 9.396615 reconstr : 7.2199 classif : 0.216025
# Val	loss : 8.934815 reconstr : 6.764884 classif : 0.20227
#
# ===> epoch: 60
# Train	loss : 9.222523 reconstr : 7.058391 classif : 0.214741
# Val	loss : 9.316755 reconstr : 7.129918 classif : 0.196949
# Model saved
#
# ===> epoch: 61
# Train	loss : 9.239969 reconstr : 7.055078 classif : 0.21381
# Val	loss : 8.968533 reconstr : 6.797481 classif : 0.194355
# Model saved
#
# ===> epoch: 62
# Train	loss : 9.145712 reconstr : 6.990064 classif : 0.213207
# Val	loss : 8.267805 reconstr : 6.173426 classif : 0.19165
# Model saved
#
# ===> epoch: 63
# Train	loss : 9.192876 reconstr : 7.056682 classif : 0.211671
# Val	loss : 9.183863 reconstr : 7.028434 classif : 0.191997
#
# ===> epoch: 64
# Train	loss : 9.278749 reconstr : 7.121832 classif : 0.212418
# Val	loss : 8.900446 reconstr : 6.71149 classif : 0.197278
#
# ===> epoch: 65
# Train	loss : 9.208239 reconstr : 7.024957 classif : 0.211109
# Val	loss : 8.666786 reconstr : 6.526369 classif : 0.189664
# Model saved
#
# ===> epoch: 66
# Train	loss : 9.213119 reconstr : 7.057728 classif : 0.207101
# Val	loss : 8.452548 reconstr : 6.2898 classif : 0.188102
# Model saved
#
# ===> epoch: 67
# Train	loss : 9.190587 reconstr : 7.00567 classif : 0.20215
# Val	loss : 8.937527 reconstr : 6.80413 classif : 0.186107
# Model saved
#
# ===> epoch: 68
# Train	loss : 9.288544 reconstr : 7.118526 classif : 0.202176
# Val	loss : 9.023747 reconstr : 6.839293 classif : 0.184471
# Model saved
#
# ===> epoch: 69
# Train	loss : 9.233673 reconstr : 7.06016 classif : 0.204434
# Val	loss : 8.82041 reconstr : 6.641871 classif : 0.190542
#
# ===> epoch: 70
# Train	loss : 9.03327 reconstr : 6.864336 classif : 0.201064
# Val	loss : 8.435053 reconstr : 6.30377 classif : 0.18379
# Model saved
#
# ===> epoch: 71
# Train	loss : 9.216991 reconstr : 7.040652 classif : 0.201128
# Val	loss : 8.900398 reconstr : 6.712348 classif : 0.181578
# Model saved
#
# ===> epoch: 72
# Train	loss : 9.31489 reconstr : 7.089824 classif : 0.199338
# Val	loss : 8.352932 reconstr : 6.151791 classif : 0.18111
# Model saved
#
# ===> epoch: 73
# Train	loss : 9.134964 reconstr : 6.957734 classif : 0.198018
# Val	loss : 8.623707 reconstr : 6.48631 classif : 0.178904
# Model saved
#
# ===> epoch: 74
# Train	loss : 9.119723 reconstr : 6.946769 classif : 0.197193
# Val	loss : 8.543796 reconstr : 6.377123 classif : 0.176493
# Model saved
#
# ===> epoch: 75
# Train	loss : 9.11776 reconstr : 6.939642 classif : 0.19254
# Val	loss : 8.561547 reconstr : 6.405046 classif : 0.174146
# Model saved
#
# ===> epoch: 76
# Train	loss : 9.146616 reconstr : 6.981904 classif : 0.193579
# Val	loss : 8.526371 reconstr : 6.400188 classif : 0.174112
# Model saved
#
# ===> epoch: 77
# Train	loss : 9.189374 reconstr : 7.037889 classif : 0.195788
# Val	loss : 8.724254 reconstr : 6.631072 classif : 0.179304
#
# ===> epoch: 78
# Train	loss : 9.124157 reconstr : 6.974858 classif : 0.20043
# Val	loss : 8.299582 reconstr : 6.171291 classif : 0.180088
#
# ===> epoch: 79
# Train	loss : 9.109369 reconstr : 6.966963 classif : 0.19395
# Val	loss : 8.350921 reconstr : 6.201829 classif : 0.175034
#
# ===> epoch: 80
# Train	loss : 9.178791 reconstr : 7.012285 classif : 0.192718
# Val	loss : 8.603132 reconstr : 6.444121 classif : 0.175313
#
# ===> epoch: 81
# Train	loss : 8.97894 reconstr : 6.842704 classif : 0.190864
# Val	loss : 9.03489 reconstr : 6.910949 classif : 0.173508
# Model saved
#
# ===> epoch: 82
# Train	loss : 9.074602 reconstr : 6.929999 classif : 0.194442
# Val	loss : 8.728465 reconstr : 6.589321 classif : 0.170535
# Model saved
#
# ===> epoch: 83
# Train	loss : 9.085254 reconstr : 6.97324 classif : 0.189698
# Val	loss : 8.512393 reconstr : 6.392984 classif : 0.174912
#
# ===> epoch: 84
# Train	loss : 9.188873 reconstr : 7.056664 classif : 0.190808
# Val	loss : 8.682916 reconstr : 6.538494 classif : 0.173409
#
# ===> epoch: 85
# Train	loss : 9.162847 reconstr : 7.010129 classif : 0.188465
# Val	loss : 8.406661 reconstr : 6.251496 classif : 0.175415
#
# ===> epoch: 86
# Train	loss : 9.09472 reconstr : 6.942997 classif : 0.187897
# Val	loss : 8.413129 reconstr : 6.253809 classif : 0.168605
# Model saved
#
# ===> epoch: 87
# Train	loss : 9.066191 reconstr : 6.911312 classif : 0.187813
# Val	loss : 8.622847 reconstr : 6.474731 classif : 0.169988
#
# ===> epoch: 88
# Train	loss : 9.001187 reconstr : 6.865483 classif : 0.184833
# Val	loss : 8.329909 reconstr : 6.243004 classif : 0.168087
# Model saved
#
# ===> epoch: 89
# Train	loss : 9.140507 reconstr : 7.003239 classif : 0.185798
# Val	loss : 8.576703 reconstr : 6.423856 classif : 0.165161
# Model saved
#
# ===> epoch: 90
# Train	loss : 9.073939 reconstr : 6.928483 classif : 0.184084
# Val	loss : 8.633706 reconstr : 6.47144 classif : 0.164721
# Model saved
#
# ===> epoch: 91
# Train	loss : 9.00778 reconstr : 6.864236 classif : 0.182904
# Val	loss : 8.3433 reconstr : 6.211528 classif : 0.166505
#
# ===> epoch: 92
# Train	loss : 9.180457 reconstr : 7.030268 classif : 0.184743
# Val	loss : 8.509258 reconstr : 6.319679 classif : 0.169187
#
# ===> epoch: 93
# Train	loss : 8.992171 reconstr : 6.832381 classif : 0.18662
# Val	loss : 8.816145 reconstr : 6.695446 classif : 0.165067
#
# ===> epoch: 94
# Train	loss : 9.038397 reconstr : 6.88624 classif : 0.182551
# Val	loss : 8.561991 reconstr : 6.420148 classif : 0.166868
#
# ===> epoch: 95
# Train	loss : 9.046692 reconstr : 6.90593 classif : 0.180266
# Val	loss : 8.890657 reconstr : 6.75312 classif : 0.159524
# Model saved
#
# ===> epoch: 96
# Train	loss : 9.016091 reconstr : 6.867361 classif : 0.178967
# Val	loss : 8.861625 reconstr : 6.729478 classif : 0.161366
#
# ===> epoch: 97
# Train	loss : 9.061579 reconstr : 6.922837 classif : 0.180844
# Val	loss : 8.880143 reconstr : 6.755022 classif : 0.159246
# Model saved
#
# ===> epoch: 98
# Train	loss : 8.952742 reconstr : 6.831218 classif : 0.180183
# Val	loss : 8.490679 reconstr : 6.382794 classif : 0.162581
#
# ===> epoch: 99
# Train	loss : 8.982107 reconstr : 6.881697 classif : 0.179638
# Val	loss : 8.561658 reconstr : 6.467981 classif : 0.161411
#
#  Best classif on validation: 0.159246
# Summary of training:
# /Users/ytatar/Yasin/01-Projects/21-04-16-KIT-SS2021-Aimat/kit-ml-natsc/Exericse_11/Utils.py:153: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
